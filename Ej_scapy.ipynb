# %%
from scapy.all import *

# %% [markdown]
# ### Creemos un paquete

# %%
ip_destino = #IP de google por ej.

puerto_destino = # Algún puerto que nos guste

puerto_origen = # Otro puerto que nos guste

# Creamos el paquete
udp_packet = #Armemos nuestro paquete. Para agregarle payload, le agregamos /RAW(load="nuestra info")

udp_packet.show() # Inspeccionamos el paquete antes de mandarlo

# Mandamos el paquete
send(udp_packet)
